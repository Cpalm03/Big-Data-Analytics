# %% [markdown]
# <a href="https://colab.research.google.com/github/Cpalm03/Big-Data-Analytics/blob/main/ICP6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Early Stopping

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# Define EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5,  # Number of epochs with no improvement after which training will be stopped
                               restore_best_weights=True)  # Restores model to best weights with the lowest validation loss

# Load Fashion MNIST data
(x_train, _), (x_test, _) = fashion_mnist.load_data()

# Normalize data to values between 0 and 1
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the 28x28 images into vectors of size 784
x_train = x_train.reshape((x_train.shape[0], 28 * 28))
x_test = x_test.reshape((x_test.shape[0], 28 * 28))

# Define the dimensions
input_dim = 28 * 28  # 784 input neurons
encoding_dim = 64    # Compress to 64 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)

# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# Create the autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train, epochs=100, batch_size=256, shuffle=True, validation_data=(x_test, x_test), callbacks=[early_stopping])

# Define the encoder model to get the compressed representation
encoder = Model(input_layer, encoded)

# Encode and decode some images from the test set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)

# Visualizing original and reconstructed images
n = 10  # Number of images to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4707 - val_loss: 0.3283
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3194 - val_loss: 0.3071
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3010 - val_loss: 0.2950
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2901 - val_loss: 0.2883
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2846 - val_loss: 0.2845
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2811 - val_loss: 0.2823
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2798 - val_loss: 0.2808
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2777 - val_loss: 0.2790
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2768 - val_loss: 0.2778
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2753 - val_loss: 0.2771
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2756 - val_loss: 0.2763
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2748 - val_loss: 0.2759
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2736 - val_loss: 0.2754
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2726 - val_loss: 0.2752
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2733 - val_loss: 0.2747
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2717 - val_loss: 0.2743
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2720 - val_loss: 0.2741
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2719 - val_loss: 0.2738
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2717 - val_loss: 0.2737
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2716 - val_loss: 0.2735
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2711 - val_loss: 0.2734
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2704 - val_loss: 0.2735
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2704 - val_loss: 0.2732
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2706 - val_loss: 0.2732
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2708 - val_loss: 0.2731
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2701 - val_loss: 0.2729
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2705 - val_loss: 0.2730
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2708 - val_loss: 0.2728
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2727
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2702 - val_loss: 0.2727
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2726
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2698 - val_loss: 0.2725
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2708 - val_loss: 0.2727
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2701 - val_loss: 0.2726
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2727
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2691 - val_loss: 0.2724
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2724
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2723
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2694 - val_loss: 0.2723
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2701 - val_loss: 0.2723
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2702 - val_loss: 0.2722
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2702 - val_loss: 0.2723
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2699 - val_loss: 0.2722
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2701 - val_loss: 0.2722
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2722
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2696 - val_loss: 0.2722
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - val_loss: 0.2722
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2721
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2693 - val_loss: 0.2723
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2720
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2721
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - val_loss: 0.2721
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2685 - val_loss: 0.2720
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2692 - val_loss: 0.2720
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2691 - val_loss: 0.2720
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - val_loss: 0.2720
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2699 - val_loss: 0.2720
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2719
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2695 - val_loss: 0.2720
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2688 - val_loss: 0.2720
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2689 - val_loss: 0.2721
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2695 - val_loss: 0.2720
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2719
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2692 - val_loss: 0.2720
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2691 - val_loss: 0.2719
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2719
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2719
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2690 - val_loss: 0.2719
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2698 - val_loss: 0.2718
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2692 - val_loss: 0.2718
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2691 - val_loss: 0.2720
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2692 - val_loss: 0.2718
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2693 - val_loss: 0.2718
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2693 - val_loss: 0.2719
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# Early Callback stopped the execution at 79 epochs due to no more improvement in the loss

# %% [markdown]
# # Terminate on NaN

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import TerminateOnNaN

# Define the TerminateOnNaN callback
terminate_on_nan = TerminateOnNaN()

# Load Fashion MNIST data
(x_train, _), (x_test, _) = fashion_mnist.load_data()

# Normalize data to values between 0 and 1
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the 28x28 images into vectors of size 784
x_train = x_train.reshape((x_train.shape[0], 28 * 28))
x_test = x_test.reshape((x_test.shape[0], 28 * 28))

# Define the dimensions
input_dim = 28 * 28  # 784 input neurons
encoding_dim = 64    # Compress to 64 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)

# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# Create the autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train, epochs=100, batch_size=256, shuffle=True, validation_data=(x_test, x_test), callbacks=[terminate_on_nan])

# Define the encoder model to get the compressed representation
encoder = Model(input_layer, encoded)

# Encode and decode some images from the test set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)

# Visualizing original and reconstructed images
n = 10  # Number of images to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.4698 - val_loss: 0.3275
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3193 - val_loss: 0.3069
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3014 - val_loss: 0.2952
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2913 - val_loss: 0.2887
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2859 - val_loss: 0.2845
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2812 - val_loss: 0.2817
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2788 - val_loss: 0.2799
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2765 - val_loss: 0.2787
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2762 - val_loss: 0.2774
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2746 - val_loss: 0.2766
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2739 - val_loss: 0.2761
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2733 - val_loss: 0.2755
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2728 - val_loss: 0.2751
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2727 - val_loss: 0.2748
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2729 - val_loss: 0.2744
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2721 - val_loss: 0.2744
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2713 - val_loss: 0.2740
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2717 - val_loss: 0.2739
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2713 - val_loss: 0.2737
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2708 - val_loss: 0.2737
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2713 - val_loss: 0.2734
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2712 - val_loss: 0.2733
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2711 - val_loss: 0.2733
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2711 - val_loss: 0.2733
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2709 - val_loss: 0.2730
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2707 - val_loss: 0.2730
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2729
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2703 - val_loss: 0.2728
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2707 - val_loss: 0.2728
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2703 - val_loss: 0.2727
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2727
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2700 - val_loss: 0.2727
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2709 - val_loss: 0.2726
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2705 - val_loss: 0.2726
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2707 - val_loss: 0.2725
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2699 - val_loss: 0.2725
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2702 - val_loss: 0.2724
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2696 - val_loss: 0.2724
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2724
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2723
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2698 - val_loss: 0.2723
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2695 - val_loss: 0.2728
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2724
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2708 - val_loss: 0.2722
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2701 - val_loss: 0.2723
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2693 - val_loss: 0.2722
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2723
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2722
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2695 - val_loss: 0.2723
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2692 - val_loss: 0.2723
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2692 - val_loss: 0.2721
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2691 - val_loss: 0.2721
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2698 - val_loss: 0.2720
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2695 - val_loss: 0.2720
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2720
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2694 - val_loss: 0.2720
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2689 - val_loss: 0.2720
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2696 - val_loss: 0.2720
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2720
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2720
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2695 - val_loss: 0.2720
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2696 - val_loss: 0.2720
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2690 - val_loss: 0.2719
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2693 - val_loss: 0.2719
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2719
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2690 - val_loss: 0.2720
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2720
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2692 - val_loss: 0.2719
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2695 - val_loss: 0.2719
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2695 - val_loss: 0.2719
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2691 - val_loss: 0.2719
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2691 - val_loss: 0.2718
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2698 - val_loss: 0.2719
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2719
# Epoch 75/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2718
# Epoch 76/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2686 - val_loss: 0.2718
# Epoch 77/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2718
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2688 - val_loss: 0.2717
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2694 - val_loss: 0.2718
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2698 - val_loss: 0.2718
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2689 - val_loss: 0.2719
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2688 - val_loss: 0.2718
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2694 - val_loss: 0.2718
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2689 - val_loss: 0.2717
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2688 - val_loss: 0.2717
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2693 - val_loss: 0.2717
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2697 - val_loss: 0.2717
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2703 - val_loss: 0.2717
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2685 - val_loss: 0.2718
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2690 - val_loss: 0.2717
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2692 - val_loss: 0.2718
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2688 - val_loss: 0.2718
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2718
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2695 - val_loss: 0.2717
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2696 - val_loss: 0.2718
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2690 - val_loss: 0.2717
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2683 - val_loss: 0.2718
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2693 - val_loss: 0.2718
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2685 - val_loss: 0.2717
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2689 - val_loss: 0.2717
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# Terminate On Nan ran all 100 epochs

# %% [markdown]
# # Model Checkpoint

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the ModelCheckpoint callback
checkpoint = ModelCheckpoint(filepath='autoencoder_best.keras',  # File path to save the model
                             monitor='val_loss',  # Metric to monitor
                             save_best_only=True,  # Save only the best model (based on the monitored metric)
                             mode='min',  # Minimize the monitored metric (e.g., validation loss)
                             save_weights_only=False,  # Save the entire model (set to True to save only weights)
                             verbose=1)  # Print a message when saving the model

# Load Fashion MNIST data
(x_train, _), (x_test, _) = fashion_mnist.load_data()

# Normalize data to values between 0 and 1
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the 28x28 images into vectors of size 784
x_train = x_train.reshape((x_train.shape[0], 28 * 28))
x_test = x_test.reshape((x_test.shape[0], 28 * 28))

# Define the dimensions
input_dim = 28 * 28  # 784 input neurons
encoding_dim = 64    # Compress to 64 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)

# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# Create the autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test), callbacks=[checkpoint])

# Define the encoder model to get the compressed representation
encoder = Model(input_layer, encoded)

# Encode and decode some images from the test set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)

# Visualizing original and reconstructed images
n = 10  # Number of images to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4717
# Epoch 1: val_loss improved from inf to 0.32796, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.4714 - val_loss: 0.3280
# Epoch 2/50
# 208/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3186
# Epoch 2: val_loss improved from 0.32796 to 0.30490, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3179 - val_loss: 0.3049
# Epoch 3/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3002
# Epoch 3: val_loss improved from 0.30490 to 0.29439, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3001 - val_loss: 0.2944
# Epoch 4/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2907
# Epoch 4: val_loss improved from 0.29439 to 0.28802, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2906 - val_loss: 0.2880
# Epoch 5/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2858
# Epoch 5: val_loss improved from 0.28802 to 0.28424, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2858 - val_loss: 0.2842
# Epoch 6/50
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2821
# Epoch 6: val_loss improved from 0.28424 to 0.28178, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2821 - val_loss: 0.2818
# Epoch 7/50
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2791
# Epoch 7: val_loss improved from 0.28178 to 0.28006, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2791 - val_loss: 0.2801
# Epoch 8/50
# 219/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2778
# Epoch 8: val_loss improved from 0.28006 to 0.27879, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2777 - val_loss: 0.2788
# Epoch 9/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2765
# Epoch 9: val_loss improved from 0.27879 to 0.27781, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2765 - val_loss: 0.2778
# Epoch 10/50
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2759
# Epoch 10: val_loss improved from 0.27781 to 0.27707, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2759 - val_loss: 0.2771
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2747
# Epoch 11: val_loss improved from 0.27707 to 0.27645, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2747 - val_loss: 0.2765
# Epoch 12/50
# 217/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2737
# Epoch 12: val_loss improved from 0.27645 to 0.27597, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2738 - val_loss: 0.2760
# Epoch 13/50
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2726
# Epoch 13: val_loss improved from 0.27597 to 0.27552, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2727 - val_loss: 0.2755
# Epoch 14/50
# 206/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2727
# Epoch 14: val_loss improved from 0.27552 to 0.27501, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2727 - val_loss: 0.2750
# Epoch 15/50
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2722
# Epoch 15: val_loss improved from 0.27501 to 0.27453, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2722 - val_loss: 0.2745
# Epoch 16/50
# 213/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2723
# Epoch 16: val_loss improved from 0.27453 to 0.27427, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2723 - val_loss: 0.2743
# Epoch 17/50
# 232/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2719
# Epoch 17: val_loss improved from 0.27427 to 0.27402, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2719 - val_loss: 0.2740
# Epoch 18/50
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2720
# Epoch 18: val_loss improved from 0.27402 to 0.27386, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2720 - val_loss: 0.2739
# Epoch 19/50
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2721
# Epoch 19: val_loss improved from 0.27386 to 0.27367, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2720 - val_loss: 0.2737
# Epoch 20/50
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2721
# Epoch 20: val_loss improved from 0.27367 to 0.27355, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2721 - val_loss: 0.2736
# Epoch 21/50
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2719
# Epoch 21: val_loss did not improve from 0.27355
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2718 - val_loss: 0.2736
# Epoch 22/50
# 209/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2720
# Epoch 22: val_loss improved from 0.27355 to 0.27329, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2719 - val_loss: 0.2733
# Epoch 23/50
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2714
# Epoch 23: val_loss did not improve from 0.27329
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2713 - val_loss: 0.2734
# Epoch 24/50
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2708
# Epoch 24: val_loss improved from 0.27329 to 0.27306, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2708 - val_loss: 0.2731
# Epoch 25/50
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 25: val_loss improved from 0.27306 to 0.27300, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2701 - val_loss: 0.2730
# Epoch 26/50
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2706
# Epoch 26: val_loss did not improve from 0.27300
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2706 - val_loss: 0.2730
# Epoch 27/50
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2708
# Epoch 27: val_loss improved from 0.27300 to 0.27298, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2708 - val_loss: 0.2730
# Epoch 28/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2708
# Epoch 28: val_loss improved from 0.27298 to 0.27276, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2708 - val_loss: 0.2728
# Epoch 29/50
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2700
# Epoch 29: val_loss did not improve from 0.27276
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2700 - val_loss: 0.2728
# Epoch 30/50
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2693
# Epoch 30: val_loss improved from 0.27276 to 0.27265, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2726
# Epoch 31/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 31: val_loss did not improve from 0.27265
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2704 - val_loss: 0.2727
# Epoch 32/50
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2702
# Epoch 32: val_loss improved from 0.27265 to 0.27262, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2726
# Epoch 33/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 33: val_loss improved from 0.27262 to 0.27258, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2726
# Epoch 34/50
# 205/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 34: val_loss improved from 0.27258 to 0.27255, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2726
# Epoch 35/50
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 35: val_loss improved from 0.27255 to 0.27254, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2701 - val_loss: 0.2725
# Epoch 36/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 36: val_loss improved from 0.27254 to 0.27252, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2701 - val_loss: 0.2725
# Epoch 37/50
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2695
# Epoch 37: val_loss did not improve from 0.27252
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2695 - val_loss: 0.2726
# Epoch 38/50
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2703
# Epoch 38: val_loss improved from 0.27252 to 0.27237, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2703 - val_loss: 0.2724
# Epoch 39/50
# 219/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 39: val_loss did not improve from 0.27237
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2701 - val_loss: 0.2724
# Epoch 40/50
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2713
# Epoch 40: val_loss improved from 0.27237 to 0.27230, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2712 - val_loss: 0.2723
# Epoch 41/50
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2703
# Epoch 41: val_loss did not improve from 0.27230
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2703 - val_loss: 0.2724
# Epoch 42/50
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2694
# Epoch 42: val_loss did not improve from 0.27230
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2723
# Epoch 43/50
# 219/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2700
# Epoch 43: val_loss improved from 0.27230 to 0.27226, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2700 - val_loss: 0.2723
# Epoch 44/50
# 215/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2700
# Epoch 44: val_loss did not improve from 0.27226
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2700 - val_loss: 0.2725
# Epoch 45/50
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 45: val_loss improved from 0.27226 to 0.27221, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2699 - val_loss: 0.2722
# Epoch 46/50
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2694
# Epoch 46: val_loss did not improve from 0.27221
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2722
# Epoch 47/50
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 47: val_loss did not improve from 0.27221
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2698 - val_loss: 0.2723
# Epoch 48/50
# 219/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 48: val_loss improved from 0.27221 to 0.27216, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2703 - val_loss: 0.2722
# Epoch 49/50
# 219/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2692
# Epoch 49: val_loss did not improve from 0.27216
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2692 - val_loss: 0.2722
# Epoch 50/50
# 217/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2697
# Epoch 50: val_loss improved from 0.27216 to 0.27213, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2721
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# The final model that was saved was from epoch 50 as it was an omprovement on the value loss over the last saved model which was on epoch 48

# %% [markdown]
# # Reduce Learning Rate On Plateau

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss',  # Metric to monitor
                              factor=0.5,  # Factor by which the learning rate will be reduced (new_lr = lr * factor)
                              patience=3,  # Number of epochs with no improvement after which learning rate will be reduced
                              min_lr=1e-6,  # Lower bound for the learning rate
                              verbose=1)  # Print message when the learning rate is reduced

# Load Fashion MNIST data
(x_train, _), (x_test, _) = fashion_mnist.load_data()

# Normalize data to values between 0 and 1
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the 28x28 images into vectors of size 784
x_train = x_train.reshape((x_train.shape[0], 28 * 28))
x_test = x_test.reshape((x_test.shape[0], 28 * 28))

# Define the dimensions
input_dim = 28 * 28  # 784 input neurons
encoding_dim = 64    # Compress to 64 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)

# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# Create the autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test), callbacks=[reduce_lr])

# Define the encoder model to get the compressed representation
encoder = Model(input_layer, encoded)

# Encode and decode some images from the test set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)

# Visualizing original and reconstructed images
n = 10  # Number of images to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4700 - val_loss: 0.3274 - learning_rate: 0.0010
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3198 - val_loss: 0.3076 - learning_rate: 0.0010
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3023 - val_loss: 0.2954 - learning_rate: 0.0010
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2899 - val_loss: 0.2888 - learning_rate: 0.0010
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2856 - val_loss: 0.2848 - learning_rate: 0.0010
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2823 - val_loss: 0.2820 - learning_rate: 0.0010
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2796 - val_loss: 0.2800 - learning_rate: 0.0010
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2774 - val_loss: 0.2785 - learning_rate: 0.0010
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2759 - val_loss: 0.2773 - learning_rate: 0.0010
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2746 - val_loss: 0.2765 - learning_rate: 0.0010
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2738 - val_loss: 0.2759 - learning_rate: 0.0010
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2740 - val_loss: 0.2754 - learning_rate: 0.0010
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2741 - val_loss: 0.2750 - learning_rate: 0.0010
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2728 - val_loss: 0.2747 - learning_rate: 0.0010
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2726 - val_loss: 0.2744 - learning_rate: 0.0010
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2722 - val_loss: 0.2742 - learning_rate: 0.0010
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2723 - val_loss: 0.2740 - learning_rate: 0.0010
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2715 - val_loss: 0.2740 - learning_rate: 0.0010
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2712 - val_loss: 0.2737 - learning_rate: 0.0010
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2716 - val_loss: 0.2735 - learning_rate: 0.0010
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2708 - val_loss: 0.2735 - learning_rate: 0.0010
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2708 - val_loss: 0.2734 - learning_rate: 0.0010
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2710 - val_loss: 0.2733 - learning_rate: 0.0010
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2730 - learning_rate: 0.0010
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2705 - val_loss: 0.2730 - learning_rate: 0.0010
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2711 - val_loss: 0.2729 - learning_rate: 0.0010
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2713 - val_loss: 0.2728 - learning_rate: 0.0010
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2728 - learning_rate: 0.0010
# Epoch 29/50
# 217/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2728 - learning_rate: 0.0010
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - val_loss: 0.2725 - learning_rate: 5.0000e-04
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2695 - val_loss: 0.2725 - learning_rate: 5.0000e-04
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2705 - val_loss: 0.2724 - learning_rate: 5.0000e-04
# Epoch 33/50
# 217/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2709
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2708 - val_loss: 0.2724 - learning_rate: 5.0000e-04
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2723 - learning_rate: 2.5000e-04
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2723 - learning_rate: 2.5000e-04
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2722 - learning_rate: 2.5000e-04
# Epoch 37/50
# 216/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2699 - val_loss: 0.2723 - learning_rate: 2.5000e-04
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2693 - val_loss: 0.2722 - learning_rate: 1.2500e-04
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2695 - val_loss: 0.2722 - learning_rate: 1.2500e-04
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2698 - val_loss: 0.2722 - learning_rate: 1.2500e-04
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2699 - val_loss: 0.2722 - learning_rate: 1.2500e-04
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2722 - learning_rate: 1.2500e-04
# Epoch 43/50
# 213/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2698 - val_loss: 0.2722 - learning_rate: 1.2500e-04
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2721 - learning_rate: 6.2500e-05
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - val_loss: 0.2721 - learning_rate: 6.2500e-05
# Epoch 46/50
# 215/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2721 - learning_rate: 6.2500e-05
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2700 - val_loss: 0.2721 - learning_rate: 3.1250e-05
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2721 - learning_rate: 3.1250e-05
# Epoch 49/50
# 219/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2694
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2694 - val_loss: 0.2721 - learning_rate: 3.1250e-05
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2694 - val_loss: 0.2721 - learning_rate: 1.5625e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# The learning rate reduces at epochs: 29, 33, 37, 43, 46, and 49

# %% [markdown]
# # All 4 Callbacks

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TerminateOnNaN, ReduceLROnPlateau

# Define EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Define the TerminateOnNaN callback
terminate_on_nan = TerminateOnNaN()

# Define the ModelCheckpoint callback
checkpoint = ModelCheckpoint(filepath='autoencoder_best.keras', monitor='val_loss', save_best_only=True, mode='min', save_weights_only=False, verbose=1)

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

# Load Fashion MNIST data
(x_train, _), (x_test, _) = fashion_mnist.load_data()

# Normalize data to values between 0 and 1
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Flatten the 28x28 images into vectors of size 784
x_train = x_train.reshape((x_train.shape[0], 28 * 28))
x_test = x_test.reshape((x_test.shape[0], 28 * 28))

# Define the dimensions
input_dim = 28 * 28  # 784 input neurons
encoding_dim = 64    # Compress to 64 features

# Define the input layer
input_layer = Input(shape=(input_dim,))

# Define the encoder
encoded = Dense(encoding_dim, activation='relu')(input_layer)

# Define the decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# Create the autoencoder model
autoencoder = Model(input_layer, decoded)

# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train, epochs=100, batch_size=256, shuffle=True, validation_data=(x_test, x_test), callbacks=[early_stopping, terminate_on_nan, checkpoint, reduce_lr])

# Define the encoder model to get the compressed representation
encoder = Model(input_layer, encoded)

# Encode and decode some images from the test set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)

# Visualizing original and reconstructed images
n = 10  # Number of images to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4728
# Epoch 1: val_loss improved from inf to 0.32884, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.4724 - val_loss: 0.3288 - learning_rate: 0.0010
# Epoch 2/100
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3202
# Epoch 2: val_loss improved from 0.32884 to 0.30805, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3199 - val_loss: 0.3080 - learning_rate: 0.0010
# Epoch 3/100
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3024
# Epoch 3: val_loss improved from 0.30805 to 0.29599, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3023 - val_loss: 0.2960 - learning_rate: 0.0010
# Epoch 4/100
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2928
# Epoch 4: val_loss improved from 0.29599 to 0.28889, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2928 - val_loss: 0.2889 - learning_rate: 0.0010
# Epoch 5/100
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2854
# Epoch 5: val_loss improved from 0.28889 to 0.28482, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2854 - val_loss: 0.2848 - learning_rate: 0.0010
# Epoch 6/100
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2818
# Epoch 6: val_loss improved from 0.28482 to 0.28232, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2818 - val_loss: 0.2823 - learning_rate: 0.0010
# Epoch 7/100
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2798
# Epoch 7: val_loss improved from 0.28232 to 0.28058, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2797 - val_loss: 0.2806 - learning_rate: 0.0010
# Epoch 8/100
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2779
# Epoch 8: val_loss improved from 0.28058 to 0.27935, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2779 - val_loss: 0.2794 - learning_rate: 0.0010
# Epoch 9/100
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2766
# Epoch 9: val_loss improved from 0.27935 to 0.27831, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2766 - val_loss: 0.2783 - learning_rate: 0.0010
# Epoch 10/100
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2760
# Epoch 10: val_loss improved from 0.27831 to 0.27746, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2760 - val_loss: 0.2775 - learning_rate: 0.0010
# Epoch 11/100
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2741
# Epoch 11: val_loss improved from 0.27746 to 0.27681, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2742 - val_loss: 0.2768 - learning_rate: 0.0010
# Epoch 12/100
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2745
# Epoch 12: val_loss improved from 0.27681 to 0.27644, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2745 - val_loss: 0.2764 - learning_rate: 0.0010
# Epoch 13/100
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2733
# Epoch 13: val_loss improved from 0.27644 to 0.27581, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2733 - val_loss: 0.2758 - learning_rate: 0.0010
# Epoch 14/100
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2736
# Epoch 14: val_loss improved from 0.27581 to 0.27524, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2736 - val_loss: 0.2752 - learning_rate: 0.0010
# Epoch 15/100
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2735
# Epoch 15: val_loss improved from 0.27524 to 0.27496, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2735 - val_loss: 0.2750 - learning_rate: 0.0010
# Epoch 16/100
# 209/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2729
# Epoch 16: val_loss improved from 0.27496 to 0.27467, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2729 - val_loss: 0.2747 - learning_rate: 0.0010
# Epoch 17/100
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2714
# Epoch 17: val_loss improved from 0.27467 to 0.27437, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2714 - val_loss: 0.2744 - learning_rate: 0.0010
# Epoch 18/100
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2717
# Epoch 18: val_loss improved from 0.27437 to 0.27417, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2717 - val_loss: 0.2742 - learning_rate: 0.0010
# Epoch 19/100
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2713
# Epoch 19: val_loss improved from 0.27417 to 0.27410, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2713 - val_loss: 0.2741 - learning_rate: 0.0010
# Epoch 20/100
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2718
# Epoch 20: val_loss improved from 0.27410 to 0.27385, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2718 - val_loss: 0.2739 - learning_rate: 0.0010
# Epoch 21/100
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2719
# Epoch 21: val_loss improved from 0.27385 to 0.27373, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2718 - val_loss: 0.2737 - learning_rate: 0.0010
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2713
# Epoch 22: val_loss did not improve from 0.27373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2713 - val_loss: 0.2737 - learning_rate: 0.0010
# Epoch 23/100
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2710
# Epoch 23: val_loss improved from 0.27373 to 0.27355, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2710 - val_loss: 0.2736 - learning_rate: 0.0010
# Epoch 24/100
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2709
# Epoch 24: val_loss improved from 0.27355 to 0.27348, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2709 - val_loss: 0.2735 - learning_rate: 0.0010
# Epoch 25/100
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2706
# Epoch 25: val_loss improved from 0.27348 to 0.27345, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2706 - val_loss: 0.2735 - learning_rate: 0.0010
# Epoch 26/100
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2707
# Epoch 26: val_loss improved from 0.27345 to 0.27337, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2707 - val_loss: 0.2734 - learning_rate: 0.0010
# Epoch 27/100
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2710
# Epoch 27: val_loss improved from 0.27337 to 0.27323, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2709 - val_loss: 0.2732 - learning_rate: 0.0010
# Epoch 28/100
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2706
# Epoch 28: val_loss did not improve from 0.27323
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2706 - val_loss: 0.2733 - learning_rate: 0.0010
# Epoch 29/100
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2706
# Epoch 29: val_loss improved from 0.27323 to 0.27322, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2706 - val_loss: 0.2732 - learning_rate: 0.0010
# Epoch 30/100
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2705
# Epoch 30: val_loss did not improve from 0.27322
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2705 - val_loss: 0.2732 - learning_rate: 0.0010
# Epoch 31/100
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2708
# Epoch 31: val_loss improved from 0.27322 to 0.27284, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2708 - val_loss: 0.2728 - learning_rate: 5.0000e-04
# Epoch 32/100
# 219/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2706
# Epoch 32: val_loss improved from 0.27284 to 0.27282, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2706 - val_loss: 0.2728 - learning_rate: 5.0000e-04
# Epoch 33/100
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 33: val_loss did not improve from 0.27282
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2701 - val_loss: 0.2728 - learning_rate: 5.0000e-04
# Epoch 34/100
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2702
# Epoch 34: val_loss did not improve from 0.27282
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2729 - learning_rate: 5.0000e-04
# Epoch 35/100
# 216/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2709
# Epoch 35: val_loss improved from 0.27282 to 0.27265, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2708 - val_loss: 0.2727 - learning_rate: 2.5000e-04
# Epoch 36/100
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2700
# Epoch 36: val_loss improved from 0.27265 to 0.27265, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2727 - learning_rate: 2.5000e-04
# Epoch 37/100
# 219/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2709
# Epoch 37: val_loss improved from 0.27265 to 0.27263, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2708 - val_loss: 0.2726 - learning_rate: 2.5000e-04
# Epoch 38/100
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2709
# Epoch 38: val_loss improved from 0.27263 to 0.27262, saving model to autoencoder_best.keras
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2709 - val_loss: 0.2726 - learning_rate: 2.5000e-04
# Epoch 39/100
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 39: val_loss improved from 0.27262 to 0.27258, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2726 - learning_rate: 1.2500e-04
# Epoch 40/100
# 213/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2702
# Epoch 40: val_loss improved from 0.27258 to 0.27256, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2726 - learning_rate: 1.2500e-04
# Epoch 41/100
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 41: val_loss improved from 0.27256 to 0.27256, saving model to autoencoder_best.keras
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2726 - learning_rate: 1.2500e-04
# Epoch 42/100
# 214/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2706
# Epoch 42: val_loss improved from 0.27256 to 0.27253, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2705 - val_loss: 0.2725 - learning_rate: 6.2500e-05
# Epoch 43/100
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2699
# Epoch 43: val_loss improved from 0.27253 to 0.27252, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2699 - val_loss: 0.2725 - learning_rate: 6.2500e-05
# Epoch 44/100
# 230/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 44: val_loss improved from 0.27252 to 0.27252, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2704 - val_loss: 0.2725 - learning_rate: 6.2500e-05
# Epoch 45/100
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 45: val_loss improved from 0.27252 to 0.27251, saving model to autoencoder_best.keras
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2725 - learning_rate: 6.2500e-05
# Epoch 46/100
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2703
# Epoch 46: val_loss improved from 0.27251 to 0.27251, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2703 - val_loss: 0.2725 - learning_rate: 3.1250e-05
# Epoch 47/100
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2693
# Epoch 47: val_loss improved from 0.27251 to 0.27250, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2693 - val_loss: 0.2725 - learning_rate: 3.1250e-05
# Epoch 48/100
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2705
# Epoch 48: val_loss did not improve from 0.27250
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2705 - val_loss: 0.2725 - learning_rate: 3.1250e-05
# Epoch 49/100
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2692
# Epoch 49: val_loss improved from 0.27250 to 0.27249, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2693 - val_loss: 0.2725 - learning_rate: 1.5625e-05
# Epoch 50/100
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2702
# Epoch 50: val_loss improved from 0.27249 to 0.27249, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2702 - val_loss: 0.2725 - learning_rate: 1.5625e-05
# Epoch 51/100
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 51: val_loss improved from 0.27249 to 0.27249, saving model to autoencoder_best.keras
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2699 - val_loss: 0.2725 - learning_rate: 1.5625e-05
# Epoch 52/100
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 52: val_loss improved from 0.27249 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2725 - learning_rate: 7.8125e-06
# Epoch 53/100
# 216/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 53: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2725 - learning_rate: 7.8125e-06
# Epoch 54/100
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2706
# Epoch 54: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2706 - val_loss: 0.2725 - learning_rate: 7.8125e-06
# Epoch 55/100
# 208/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2695
# Epoch 55: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2695 - val_loss: 0.2725 - learning_rate: 3.9063e-06
# Epoch 56/100
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2697
# Epoch 56: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 3.9063e-06
# Epoch 57/100
# 212/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2693
# Epoch 57: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2693 - val_loss: 0.2725 - learning_rate: 3.9063e-06
# Epoch 58/100
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2696
# Epoch 58: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - val_loss: 0.2725 - learning_rate: 1.9531e-06
# Epoch 59/100
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 59: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2699 - val_loss: 0.2725 - learning_rate: 1.9531e-06
# Epoch 60/100
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2701
# Epoch 60: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1e-06.
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2700 - val_loss: 0.2725 - learning_rate: 1.9531e-06
# Epoch 61/100
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2692
# Epoch 61: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2693 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 62/100
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 62: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 63/100
# 223/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2703
# Epoch 63: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2703 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 64/100
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 64: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 65/100
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2706
# Epoch 65: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2706 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 66/100
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 66: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 67/100
# 217/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 67: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 68/100
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2703
# Epoch 68: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2703 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 69/100
# 216/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 69: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 70/100
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2694
# Epoch 70: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2694 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 71/100
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2697
# Epoch 71: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 72/100
# 213/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 72: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2701 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 73/100
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2698
# Epoch 73: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 74/100
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2696
# Epoch 74: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 75/100
# 214/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2695
# Epoch 75: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 76/100
# 234/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2696
# Epoch 76: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2696 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 77/100
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2700
# Epoch 77: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2700 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 78/100
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2698
# Epoch 78: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 79/100
# 215/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 79: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2701 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 80/100
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 80: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 81/100
# 217/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2696
# Epoch 81: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2696 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 82/100
# 233/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2700
# Epoch 82: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 83/100
# 217/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 83: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 84/100
# 218/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2699
# Epoch 84: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2699 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 85: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 86/100
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2705
# Epoch 86: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 87/100
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 87: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 88/100
# 224/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2692
# Epoch 88: val_loss did not improve from 0.27248
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2692 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 89/100
# 208/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2700
# Epoch 89: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 90/100
# 214/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2693
# Epoch 90: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2693 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 91/100
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2704
# Epoch 91: val_loss improved from 0.27248 to 0.27248, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2704 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 92/100
# 215/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 92: val_loss improved from 0.27248 to 0.27247, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 93/100
# 215/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 93: val_loss improved from 0.27247 to 0.27247, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 94/100
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2704
# Epoch 94: val_loss did not improve from 0.27247
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2704 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 95/100
# 222/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2702
# Epoch 95: val_loss improved from 0.27247 to 0.27247, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2702 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 96/100
# 212/235 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2700
# Epoch 96: val_loss did not improve from 0.27247
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2700 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 97/100
# 220/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 97: val_loss improved from 0.27247 to 0.27247, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 98/100
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2697
# Epoch 98: val_loss did not improve from 0.27247
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2697 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 99/100
# 213/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2700
# Epoch 99: val_loss improved from 0.27247 to 0.27247, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2700 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# Epoch 100/100
# 216/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2701
# Epoch 100: val_loss improved from 0.27247 to 0.27247, saving model to autoencoder_best.keras
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2701 - val_loss: 0.2725 - learning_rate: 1.0000e-06
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# # Load Saved Model

# %%
from tensorflow.keras.models import load_model

# Load the entire model
best_autoencoder = load_model('autoencoder_best.keras')
reconstructed_images = best_autoencoder.predict(x_test)

# Visualizing original and reconstructed images
n = 10  # Number of images to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(reconstructed_images[i].reshape(28, 28), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
